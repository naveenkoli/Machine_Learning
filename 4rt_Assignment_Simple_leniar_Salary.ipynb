# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sn

# %%
data = pd.read_csv("C:\\Users\\hp\\Downloads\\Salary_Data.csv")
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data1 = data.rename({"YearsExperience" : "Exp"},axis=1)
data1.head()
# Out:
#    Exp   Salary
# 0  1.1  39343.0
# 1  1.3  46205.0
# 2  1.5  37731.0
# 3  2.0  43525.0
# 4  2.2  39891.0

# %%
plt.boxplot(data1.Salary)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15dbb6b7730>,
#   <matplotlib.lines.Line2D at 0x15dbb6b7a00>],
#  'caps': [<matplotlib.lines.Line2D at 0x15dbb6b7d90>,
#   <matplotlib.lines.Line2D at 0x15dbb6c5160>],
#  'boxes': [<matplotlib.lines.Line2D at 0x15dbb6b72e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x15dbb6c54f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15dbb6c5880>],
#  'means': []}

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Exp     30 non-null     float64
#  1   Salary  30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
plt.scatter(data1.Exp, data1.Salary)

# %%
data1.corr()
# Out:
#              Exp    Salary
# Exp     1.000000  0.978242
# Salary  0.978242  1.000000

# %%
model = smf.ols('Salary~Exp',data=data1).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Mon, 07 Mar 2022   Prob (F-statistic):           1.14e-20
# Time:                        14:51:48   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.579e+04   2273.053     11.347      0.000    2.11e+04    3.04e+04
# Exp         9449.9623    378.755     24.950      0.000    8674.119    1.02e+04
# ==============================================================================
# Omnibus:                        2.140   Durbin-Watson:                   1.648
# Prob(Omnibus):                  0.343   Jarque-Bera (JB):                1.569
# Skew:                           0.363   Prob(JB):                        0.456
# Kurtosis:                       2.147   Cond. No.                         13.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
log_Exp = np.log(data1.Exp)

# %%
model2 = smf.ols('Salary~log_Exp',data=data1).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     163.6
# Date:                Mon, 07 Mar 2022   Prob (F-statistic):           3.25e-13
# Time:                        14:52:48   Log-Likelihood:                -319.77
# No. Observations:                  30   AIC:                             643.5
# Df Residuals:                      28   BIC:                             646.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.493e+04   5156.226      2.895      0.007    4365.921    2.55e+04
# log_Exp     4.058e+04   3172.453     12.792      0.000    3.41e+04    4.71e+04
# ==============================================================================
# Omnibus:                        1.094   Durbin-Watson:                   0.512
# Prob(Omnibus):                  0.579   Jarque-Bera (JB):                0.908
# Skew:                           0.156   Prob(JB):                        0.635
# Kurtosis:                       2.207   Cond. No.                         5.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
log_Salary = np.log(data1.Salary)

# %%
model3 = smf.ols('log_Salary~Exp',data=data1).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_Salary   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     383.6
# Date:                Mon, 07 Mar 2022   Prob (F-statistic):           7.03e-18
# Time:                        15:27:18   Log-Likelihood:                 28.183
# No. Observations:                  30   AIC:                            -52.37
# Df Residuals:                      28   BIC:                            -49.56
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.5074      0.038    273.327      0.000      10.429      10.586
# Exp            0.1255      0.006     19.585      0.000       0.112       0.139
# ==============================================================================
# Omnibus:                        0.826   Durbin-Watson:                   1.438
# Prob(Omnibus):                  0.661   Jarque-Bera (JB):                0.812
# Skew:                           0.187   Prob(JB):                        0.666
# Kurtosis:                       2.286   Cond. No.                         13.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# as we can see for model 3 we are getting Rsquared values is 93% and also the AIC value are less compared with the other model

# %%
predict_salary = np.exp(model3.predict(data1))
predict_salary
# Out:
# 0      41998.957468
# 1      43066.066794
# 2      44160.289228
# 3      47019.029189
# 4      48213.688474
# 5      52639.142472
# 6      53303.675386
# 7      54658.014935
# 8      54658.014935
# 9      58196.330788
# 10     59674.982903
# 11     60428.338456
# 12     60428.338456
# 13     61191.204604
# 14     64340.199291
# 15     67651.246149
# 16     69370.128712
# 17     71132.684635
# 18     76693.630780
# 19     77661.835040
# 20     85860.704208
# 21     89153.725393
# 22     98565.809591
# 23    102346.110512
# 24    108971.540758
# 25    113150.933364
# 26    120475.819601
# 27    121996.743836
# 28    133194.621344
# 29    136578.829694
# dtype: float64

# %%
newdata = pd.Series([2.5,3.5])

# %%
pred_salary = pd.DataFrame(newdata, columns=['Exp'])

# %%
np.exp(model3.predict(pred_salary))
# Out:
# 0    50062.831211
# 1    56754.317344
# dtype: float64
